# %%
import pandas as pd

# load dataset
df = pd.read_csv(
    "household_power_consumption.txt",
    sep=";",
    low_memory=False,
    na_values=["?"]
)

print(df.head())
# Out:
#          Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00                4.216                  0.418   234.84
# 1  16/12/2006  17:25:00                5.360                  0.436   233.63
# 2  16/12/2006  17:26:00                5.374                  0.498   233.29
# 3  16/12/2006  17:27:00                5.388                  0.502   233.74
# 4  16/12/2006  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %%
df["datetime"] = pd.to_datetime(df["Date"] + " " + df["Time"])

df = df.set_index("datetime")

df["Global_active_power"] = pd.to_numeric(df["Global_active_power"], errors="coerce")

df = df.dropna()
# Out:
# C:\Users\anush\AppData\Local\Temp\ipykernel_30024\191425056.py:1: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["datetime"] = pd.to_datetime(df["Date"] + " " + df["Time"])

# %%
data = daily_power.values.reshape(-1,1)

# %%
X = []
y = []

for i in range(30, len(data)):
    X.append(data[i-30:i])
    y.append(data[i])

X = np.array(X)
y = np.array(y)

# %%
split = int(len(X)*0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(30,1)),
    LSTM(50),
    Dense(1)
])

optimizer = Adam(learning_rate=0.001, clipvalue=1.0)

model.compile(
    optimizer=optimizer,
    loss="mse"
)

model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: nan - val_loss: nan
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: nan - val_loss: nan
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: nan - val_loss: nan
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: nan - val_loss: nan
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: nan - val_loss: nan
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: nan - val_loss: nan
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: nan - val_loss: nan
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: nan - val_loss: nan
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: nan - val_loss: nan
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: nan - val_loss: nan
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: nan - val_loss: nan
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: nan - val_loss: nan
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: nan - val_loss: nan
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: nan - val_loss: nan
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: nan - val_loss: nan
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: nan - val_loss: nan
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: nan - val_loss: nan
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: nan - val_loss: nan

# %%
import joblib
import os


model.save("energy_lstm_model.keras")
joblib.dump(scaler, "scaler.save")
# Out:
# ['models/scaler.save']
